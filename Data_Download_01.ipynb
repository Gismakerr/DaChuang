# %%
import h5py
import numpy as np
import pandas as pd
import xarray as xr
from Utils import *
from  Download import *
import geopandas as gpd
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
auth = earthaccess.login()

# %%
short_name = 'SWOT_L2_HR_Raster_2.0'
start_date = "2024-10-01"
end_date = "2025-02-01"
granule_name = "*100m*"
extent_path = r"E:\Haoyu_space\05_Presentation\ICESheet2\extent\polygon.shp"
download_dir = r"E:\Haoyu_space\05_Presentation\ICESheet2\Raster"

# %%
results = search_swot_data(start_date, end_date, extent_path, granule_pattern = granule_name,  short_name = short_name)
download_swot_granules(results, download_dir)
# Out:
# 📍 Using shapefile for spatial filter: E:\Haoyu_space\05_Presentation\ICESheet2\extent\polygon.shp
# 🗺️  Bounding box: (-49.78140096299995, 61.70547742000008, -37.562113617999955, 67.55860665300008)
# 🔍 Searching data from 2024-10-01 to 2025-02-01...
# ✅ Found 382 matching files.
# 📦 Estimated total size: 22066.22 MB
#
# ⬇️ Preparing download to: E:\Haoyu_space\05_Presentation\ICESheet2\Raster
#
# ⬇️ Downloading 382 new files...
# QUEUEING TASKS | :   0%|          | 0/382 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/382 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/382 [00:00<?, ?it/s]
# 📊 Summary:
# 🔢 Total granules in search: 382
# ✅ Skipped (already downloaded): 0
# 🗑️ Removed corrupted files: 0
# ⬇️ Newly downloaded: 382
# [WindowsPath('E:/Haoyu_space/05_Presentation/ICESheet2/Raster/SWOT_L2_HR_Raster_100m_UTM22W_N_x_x_x_022_007_138F_20241001T151456_20241001T151517_PIC0_01.nc'),
# ...
